# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from apyori import apriori
import networkx as nx
# %matplotlib inline

# %%
data = pd.read_csv("Sample_from_Million_Playlist.csv")

# %%
data.head()
# Out:
#    pid  pos     artist_name                             track_uri  \
# 0    0    0            Onyx  spotify:track:0W2mz7mvaBaEsC4rmoRNPn
# 1    0    1          M.O.P.  spotify:track:5osSw3tL07Tuid7AWsvYcc
# 2    0    2  Pharoahe Monch  spotify:track:4P2q1rzZ0XVb2vs3KSUXNF
# 3    0    3         KRS-One  spotify:track:0H7wdsHwWmKGPbGtBGS9DM
# 4    0    4            EPMD  spotify:track:5JKSty49E9iv1Tj6lfx68n
#
#                               artist_uri  \
# 0  spotify:artist:10Khz9BDdDT2mzm3330Cvu
# 1  spotify:artist:1BH45DVSTeGBvcYXNCd67g
# 2  spotify:artist:5DKuVtlpDH0agZQUFDy8O7
# 3  spotify:artist:2gINJ8xw86xawPyGvx1bla
# 4  spotify:artist:3zpKjsMg2gw1St5WcWoUJN
#
#                                           track_name  \
# 0                                               Slam
# 1  Ante Up Remix (featuring Busta Rhymes, Teflon,...
# 2                                         Simon Says
# 3                                 Sound of da Police
# 4                                          Crossover
#
#                               album_uri  duration_ms  \
# 0  spotify:album:5lUgtggG1KroP0qHkpxQ4K       218506
# 1  spotify:album:0mw0v424Ribwwrt0oMVB1j       247693
# 2  spotify:album:0toc7WsDdJVklvJRhPeIJS       173186
# 3  spotify:album:16nNpg9tlbPAzJA23wLChs       258386
# 4  spotify:album:3eu9Vmn3nODuKhqDPqDmFq       228760
#
#                                         album_name
# 0                                       Bacdafucup
# 1                                         Warriorz
# 2                         Straight Outta Old Skool
# 3  The Essential Boogie Down Productions / KRS-One
# 4                          Business Never Personal

# %%
artist_uri = data.artist_uri.to_list()
artist_name = data.artist_name.to_list()

name2uri = {}

for uri,name in zip(artist_uri,artist_name):
    name2uri[name] = uri

# %%
len(artist_uri)
# Out:
# 663192

# %%
data["pid"].unique()
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999])

# %%
data.isnull().sum()
# Out:
# pid            0
# pos            0
# artist_name    0
# track_uri      0
# artist_uri     0
# track_name     0
# album_uri      0
# duration_ms    0
# album_name     0
# dtype: int64

# %%
len(list(data.track_name.unique()))
# Out:
# 134103

# %%
values = list(data['artist_name'].value_counts())
names = data['artist_name'].value_counts().index.tolist()

ax = sns.barplot(y=names[0:25], x=values[0:25])
ax.set_title('Artists with most featured songs across all dataset')
ax.set_xlabel('Total songs across dataset')
# Out:
# Text(0.5, 0, 'Total songs across dataset')

# %%
playlist2artists = {}

for pid,artist_name in zip(data.pid.tolist(),data.artist_name.tolist()):
    if pid in playlist2artists:
        playlist2artists[pid].append(artist_name)
    else:
        playlist2artists[pid] = [artist_name]

# %%
playlist2artists[0]
# Out:
# ['Onyx',
#  'M.O.P.',
#  'Pharoahe Monch',
#  'KRS-One',
#  'EPMD',
#  'Fugees',
#  'Busta Rhymes',
#  'Westside Connection',
#  'Geto Boys',
#  'Big Pun',
#  'Blahzay Blahzay',
#  'Westside Connection',
#  'Crooklyn Dodgers',
#  'FU-Schnickens',
#  'Masta Ace Incorporated',
#  'The D.O.C.']

# %%
import re
import string

def clean_text(text):
    text = text.lower()
    text = re.sub(r"[-()\"#/$@;:<>{}`+=~|.!?,]", "", text)
    text = text.rstrip(string.digits).lstrip(string.digits)
    text = text.replace("'","")
    text = text.replace('"',"")
    text = text.replace("&","")
    return text

# %%
clean_text(""""macklemore_&_ryan_lewis""")
# Out:
# 'macklemore__ryan_lewis'

# %%
association_rules = apriori(playlist2artists.values(), min_support=0.0230, min_confidence=0.0230, min_lift=3,max_length=2, min_length=2)

# %%
artists = set()

related_name2uri = {}
for item in association_rules:
    pair = item[0] 
    items = [x for x in pair]
    first_item = items[0]    
    second_item = items[1]
    confidence = float(item[2][0][2])
    artists.add(first_item)
    artists.add(second_item)
    first_uri = name2uri[first_item]
    second_uri = name2uri[second_item]
    related_name2uri[first_item] = first_uri
    related_name2uri[second_item] = second_uri

# %%
related_name2uri.keys()
# Out:
# dict_keys(['Big Sean', '2 Chainz', 'DJ Khaled', 'Drake', 'Future', 'Gucci Mane', 'J. Cole', 'Kanye West', 'Kendrick Lamar', 'Lil Uzi Vert', 'Migos', 'Post Malone', 'Rae Sremmurd', 'Travis Scott', 'Wiz Khalifa', 'Young Thug', '21 Savage', 'Kodak Black', '50 Cent', 'A Boogie Wit da Hoodie', 'A$AP Ferg', 'A$AP Rocky', 'JAY Z', 'Lil Wayne', 'Ed Sheeran', 'Adele', 'Aminé', 'Beyoncé', 'Ariana Grande', 'Calvin Harris', 'Justin Bieber', 'The Chainsmokers', 'Avicii', 'B.o.B', 'Bruno Mars', 'Chris Brown', 'Flo Rida', 'Jason Derulo', 'Justin Timberlake', 'Katy Perry', 'Miley Cyrus', 'Nicki Minaj', 'Rihanna', 'Usher', 'Chance The Rapper', 'Childish Gambino', 'DRAM', 'Fetty Wap', 'French Montana', 'G-Eazy', 'Jeremih', 'KYLE', 'Logic', 'Meek Mill', 'The Weeknd', 'Ty Dolla $ign', 'Tyga', 'Britney Spears', 'Maroon 5', 'Bryson Tiller', 'DJ Snake', 'David Guetta', 'Kygo', 'Major Lazer', 'Martin Garrix', 'Zedd', 'Trey Songz', 'Coldplay', 'Demi Lovato', 'Desiigner', 'Kevin Gates', 'Kid Ink', 'Lil Yachty', 'Mac Miller', 'PARTYNEXTDOOR', 'Russ', 'ScHoolboy Q', 'T-Pain', 'T.I.', 'Waka Flocka Flame', 'Wale', 'YG', 'Yo Gotti', 'Imagine Dragons', 'John Mayer', 'Sam Smith', 'Shawn Mendes', 'Eminem', 'Pitbull', 'Flume', 'Kid Cudi', 'Snoop Dogg', 'Khalid', 'Lady Gaga', 'OneRepublic', 'Nelly', 'Selena Gomez', 'Sia', 'Twenty One Pilots', 'Zara Larsson'])

# %%
import requests 

z = 1
related_uri_name_artists = []


for name,uri in zip(related_name2uri.keys(),related_name2uri.values()):
    artist_list = []
    uri_key = uri.split(":")[2]
    response = requests.get(f"https://api.spotify.com/v1/artists/{uri_key}/related-artists", headers={"Authorization": "Bearer BQDINXGFu2ch3pj3LHeIuPhjfKTlpr5ovr0hpyqgnqnp9KtxXLxghuK2EcwV4mCA6qMLXkE0RghL2zpXs6FIpFmQ_n3WxHNVtb2WTW18LHYEqwJ97C9Xph0wV3qhHFEq-SJibg82ee7C3TsWszzN7Zvr4rGYolBwS4Ci1CqlEelQqQgip8pCHq953Tf7h8wBJJxCC13bzubBS9J8cUm31w8DCWJdomxB99gbT_GwY0ABHH63aQ2NzSF4i2TIbryr8TdeNGKts-fi_kvOtdIbBGU"})
    result = response.json()
    print(response)
    for artist in result["artists"]:
        artist_list.append(artist["name"])
    related_uri_name_artists.append([uri,name,artist_list])
    print(len(artist_list))
    print(z)
    z += 1
    
import pickle
filename = 'spotify_ground_truth_data.pkl'
outfile = open(filename,'wb')
pickle.dump(related_uri_name_artists,outfile)
outfile.close()
# Out:
# <Response [401]>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-7d0db9092500> in <module>
#      12     result = response.json()
#      13     print(response)
# ---> 14     for artist in result["artists"]:
#      15         artist_list.append(artist["name"])
#      16     related_uri_name_artists.append([uri,name,artist_list])
#
# KeyError: 'artists'

# %%
import pickle
infile = open("spotify_ground_truth_data.pkl",'rb')
new_dict = pickle.load(infile)
infile.close()
new_dict[0]
# Out:
# ['spotify:artist:17lzZA2AlOHwCwFALHttmp',
#  '2_Chainz',
#  ['DJ_Drama',
#   'Waka_Flocka_Flame',
#   'Juicy_J',
#   'Yo_Gotti',
#   'Rick_Ross',
#   'Young_Money',
#   'Ace_Hood',
#   'Wale',
#   'Jeezy',
#   'Birdman',
#   'Mike_WiLL_Made-It',
#   'Big_K.R.I.T.',
#   'Curren$y',
#   'Gucci_Mane',
#   'Rich_Homie_Quan',
#   'Young_Scooter',
#   'Young_Dolph',
#   'Quavo',
#   'Jay_Rock',
#   'French_Montana']]

# %%
clear_dict
filename = 'clear_related_data.pkl'
outfile = open(filename,'wb')
pickle.dump(clear_dict,outfile)

# %%
clear_dict = []
blank = "_"

for d in new_dict:
    artists = list()
    for item in d[2]:
        artists.append(blank.join(item.split(" ")))
    clear_dict.append([d[0],blank.join(d[1].split(" ")),artists])

# %%
all_artists = []
for _,_,artists in related_uri_name_artists:
    all_artists.extend(artists)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b25a94980ca1> in <module>
#       1 all_artists = []
# ----> 2 for _,_,artists in related_uri_name_artists:
#       3     all_artists.extend(artists)
#
# NameError: name 'related_uri_name_artists' is not defined

# %%
len(set(all_artists).intersection(list(related_name2uri.keys())))
# Out:
# 0

# %%
association_rules = apriori(playlist2artists.values(), min_support=0.0230, min_confidence=0.0230, min_lift=3,max_length=2, min_length=2)

# %%
association_rules
# Out:
# <generator object apriori at 0x1a227880d0>

# %%
node1 = []
node2 = []
weight = []


query = "CREATE "
blank = "_"

relations = {}
nodes = set()

curr = 0

z = 0
for item in association_rules:
    
   
    curr += 1
    pair = item[0] 
    items = [x for x in pair]

    first_item = clean_text(blank.join(items[0].split(" ")))
    second_item = clean_text(blank.join(items[1].split(" ")))
    first_confidence = float(item[2][0][2])
    second_confidence = float(item[2][1][2])
    first = blank.join(items[0].split(" "))
    second = blank.join(items[1].split(" "))
    support = float(item[1])

    if first_item not in nodes:
        query += f"({first_item}:artist" + " {name: " +  f'"{first}"'+ "}),"
        nodes.add(first_item)
    if second_item not in nodes:
        query += f"({second_item}:artist" + " {name: " + f'"{second}"' + "}),"
        nodes.add(second_item)
    node1.append(first_item)
    node2.append(second_item)
    weight.append(first_confidence)

    composite_key = first_item + second_item
    if composite_key not in relations.keys():
        query += f"({first_item})-[:sup_rel " + "{" + f"supp: {support}" + "}]" + f"->({second_item}),"
        relations[first_item + second_item] = float(item[1])
        
    composite_key2 = second_item + first_item
    if composite_key2 not in relations.keys():
        query += f"({second_item})-[:sup_rel " + "{" + f"supp: {support}" + "}]" + f"->({first_item}),"
        relations[second_item + first_item] = float(item[1])
    
    query += f"({first_item})-[:conf_rel " + "{" + f"conf: {first_confidence}" + "}]" + f"->({second_item}),"
    query += f"({second_item})-[:conf_rel " + "{" + f"conf: {second_confidence}" + "}]" + f"->({first_item}),"
    #    relations[first_item + second_item] = float(item[1])
    #    z += 1

# %%
query = query[:-1]
query
# Out:
# 'CREATE (_chainz:artist {name: "2_Chainz"}),(big_sean:artist {name: "Big_Sean"}),(_chainz)-[:sup_rel {supp: 0.0298}]->(big_sean),(big_sean)-[:sup_rel {supp: 0.0298}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.5359712230215827}]->(big_sean),(big_sean)-[:conf_rel {conf: 0.31601272534464475}]->(_chainz),(dj_khaled:artist {name: "DJ_Khaled"}),(_chainz)-[:sup_rel {supp: 0.0244}]->(dj_khaled),(dj_khaled)-[:sup_rel {supp: 0.0244}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.4388489208633094}]->(dj_khaled),(dj_khaled)-[:conf_rel {conf: 0.30012300123001234}]->(_chainz),(drake:artist {name: "Drake"}),(_chainz)-[:sup_rel {supp: 0.0423}]->(drake),(drake)-[:sup_rel {supp: 0.0423}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.7607913669064749}]->(drake),(drake)-[:conf_rel {conf: 0.2113943028485757}]->(_chainz),(future:artist {name: "Future"}),(_chainz)-[:sup_rel {supp: 0.0344}]->(future),(future)-[:sup_rel {supp: 0.0344}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.6187050359712231}]->(future),(future)-[:conf_rel {conf: 0.3663471778487753}]->(_chainz),(gucci_mane:artist {name: "Gucci_Mane"}),(_chainz)-[:sup_rel {supp: 0.0231}]->(gucci_mane),(gucci_mane)-[:sup_rel {supp: 0.0231}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.4154676258992806}]->(gucci_mane),(gucci_mane)-[:conf_rel {conf: 0.4978448275862069}]->(_chainz),(j_cole:artist {name: "J._Cole"}),(_chainz)-[:sup_rel {supp: 0.026}]->(j_cole),(j_cole)-[:sup_rel {supp: 0.026}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.4676258992805755}]->(j_cole),(j_cole)-[:conf_rel {conf: 0.28985507246376807}]->(_chainz),(kanye_west:artist {name: "Kanye_West"}),(_chainz)-[:sup_rel {supp: 0.0287}]->(kanye_west),(kanye_west)-[:sup_rel {supp: 0.0287}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.5161870503597122}]->(kanye_west),(kanye_west)-[:conf_rel {conf: 0.2096420745069394}]->(_chainz),(kendrick_lamar:artist {name: "Kendrick_Lamar"}),(_chainz)-[:sup_rel {supp: 0.0368}]->(kendrick_lamar),(kendrick_lamar)-[:sup_rel {supp: 0.0368}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.6618705035971223}]->(kendrick_lamar),(kendrick_lamar)-[:conf_rel {conf: 0.29160063391442154}]->(_chainz),(lil_uzi_vert:artist {name: "Lil_Uzi_Vert"}),(_chainz)-[:sup_rel {supp: 0.0265}]->(lil_uzi_vert),(lil_uzi_vert)-[:sup_rel {supp: 0.0265}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.47661870503597126}]->(lil_uzi_vert),(lil_uzi_vert)-[:conf_rel {conf: 0.4070660522273425}]->(_chainz),(migos:artist {name: "Migos"}),(_chainz)-[:sup_rel {supp: 0.0298}]->(migos),(migos)-[:sup_rel {supp: 0.0298}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.5359712230215827}]->(migos),(migos)-[:conf_rel {conf: 0.39892904953145913}]->(_chainz),(post_malone:artist {name: "Post_Malone"}),(_chainz)-[:sup_rel {supp: 0.0257}]->(post_malone),(post_malone)-[:sup_rel {supp: 0.0257}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.46223021582733814}]->(post_malone),(post_malone)-[:conf_rel {conf: 0.28651059085841696}]->(_chainz),(rae_sremmurd:artist {name: "Rae_Sremmurd"}),(_chainz)-[:sup_rel {supp: 0.0279}]->(rae_sremmurd),(rae_sremmurd)-[:sup_rel {supp: 0.0279}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.5017985611510792}]->(rae_sremmurd),(rae_sremmurd)-[:conf_rel {conf: 0.3398294762484775}]->(_chainz),(travis_scott:artist {name: "Travis_Scott"}),(_chainz)-[:sup_rel {supp: 0.0264}]->(travis_scott),(travis_scott)-[:sup_rel {supp: 0.0264}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.47482014388489213}]->(travis_scott),(travis_scott)-[:conf_rel {conf: 0.38316400580551524}]->(_chainz),(wiz_khalifa:artist {name: "Wiz_Khalifa"}),(_chainz)-[:sup_rel {supp: 0.0233}]->(wiz_khalifa),(wiz_khalifa)-[:sup_rel {supp: 0.0233}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.4190647482014389}]->(wiz_khalifa),(wiz_khalifa)-[:conf_rel {conf: 0.3098404255319149}]->(_chainz),(young_thug:artist {name: "Young_Thug"}),(_chainz)-[:sup_rel {supp: 0.024}]->(young_thug),(young_thug)-[:sup_rel {supp: 0.024}]->(_chainz),(_chainz)-[:conf_rel {conf: 0.43165467625899284}]->(young_thug),(young_thug)-[:conf_rel {conf: 0.4247787610619469}]->(_chain ...

# %%
from neo4j import GraphDatabase

# %%
uri             = "bolt://localhost:7687"
userName        = "neo4j"
password        = "123"
graphDB_Driver  = GraphDatabase.driver(uri, auth=(userName, password))
cqlNodeQuery          = "MATCH (x:artist) RETURN x"

# %%
with graphDB_Driver.session() as graphDB_Session:

    # Create nodes

    graphDB_Session.run(query)

# %%
import pandas as pd
  
df = pd.DataFrame(list(zip(node1, node2,weight)),
               columns =['node_1', 'node_2', 'distance'])
df.head()
# Out:
#     node_1      node_2  distance
# 0  _chainz    big_sean  0.535971
# 1  _chainz   dj_khaled  0.438849
# 2  _chainz       drake  0.760791
# 3   future     _chainz  0.618705
# 4  _chainz  gucci_mane  0.415468

# %%
G = nx.from_pandas_edgelist(df = df, source = 'node_1', target = 'node_2', edge_attr='distance')
G.add_nodes_from(nodes_for_adding = df['node_1'].tolist())

edge_all = [(u,v) for (u,v,d) in G.edges(data=True)]

pos=nx.spring_layout(G)
plt.figure(figsize=(40,30))
nx.draw_networkx_nodes(G,pos,node_size=10)                 # draw nodes
nx.draw_networkx_edges(G,pos,edgelist=edge_all,width=0.08) # draw edges

# %%
G = nx.from_pandas_edgelist(df = edges, source = 'node_1', target = 'node_2', edge_attr='distance')
G.add_nodes_from(nodes_for_adding = edges['node_1'].tolist())

edge_all = [(u,v) for (u,v,d) in G.edges(data=True)]

pos=nx.spring_layout(G)
plt.figure(figsize=(40,30))
nx.draw_networkx_nodes(G,pos,node_size=10)                 # draw nodes
nx.draw_networkx_edges(G,pos,edgelist=edge_all,width=0.08) # draw edges
